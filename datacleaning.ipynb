# %%
import pandas as pd

# Load the JSON file into a DataFrame
df = pd.read_json('01-armraise-39samples.json')

# Display the DataFrame
print(df)
# Out:
#                                                Relbow  \
# 0   {'x': [0.353859543800354, 0.355787366628646, 0...
# 1   {'x': [0.353859543800354, 0.355787366628646, 0...
# 2   {'x': [0.353859543800354, 0.355787366628646, 0...
# 3   {'x': [0.353859543800354, 0.355787366628646, 0...
# 4   {'x': [0.353859543800354, 0.355787366628646, 0...
# 5   {'x': [0.353859543800354, 0.355787366628646, 0...
# 6   {'x': [0.353859543800354, 0.355787366628646, 0...
# 7   {'x': [0.353859543800354, 0.355787366628646, 0...
# 8   {'x': [0.353859543800354, 0.355787366628646, 0...
# 9   {'x': [0.353859543800354, 0.355787366628646, 0...
# 10  {'x': [0.353859543800354, 0.355787366628646, 0...
# 11  {'x': [0.353859543800354, 0.355787366628646, 0...
# 12  {'x': [0.353859543800354, 0.355787366628646, 0...
# 13  {'x': [0.353859543800354, 0.355787366628646, 0...
# 14  {'x': [0.353859543800354, 0.355787366628646, 0...
# 15  {'x': [0.353859543800354, 0.355787366628646, 0...
# ...

# %%
df.describe()
# Out:
#                                                    Relbow  \
# count                                                  39
# unique                                                  1
# top     {'x': [0.353859543800354, 0.355787366628646, 0...
# freq                                                   39
#
#                                                    Rwrist  \
# count                                                  39
# unique                                                  1
# top     {'x': [0.290119498968124, 0.29626247286796503,...
# freq                                                   39
#
#                                                 Rshoulder  \
# count                                                  39
# unique                                                  1
# top     {'x': [0.43168002367019603, 0.4313430190086360...
# freq                                                   39
#
#                                                    Lelbow  \
# ...
